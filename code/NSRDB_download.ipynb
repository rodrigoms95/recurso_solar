# %%
import os
import pandas as pd
import numpy as np

# %%
# Coordenadas.
#lat = np.arange(18.09, 20.69, 0.04)
#lon = np.arange(-100.46, -97.259, 0.04)
lat = np.arange(18.08, 20.70, 0.02)
lon = np.arange(-100.47, -97.27, 0.02)
# You must request an NSRDB api key from the link above
#api_key = "vGnsS1lJcyC5dRKax0H9QIs5e6ottm05OB3uzRRL"
api_key = "rzX1wbpMOa9fbeBqDfSk3TRcQSf40Ql7ZDk4t50v"
#api_key = "XmMWV5ub8RTjyqBGPsjMtmrizT2LaHlhRrxdxylj"
# Set the attributes to extract (e.g., dhi, ghi, etc.), separated by commas.
#attributes = ( "air_temperature,dew_point,dni,dhi,ghi,relative_humidity," +
#    "solar_zenith_angle,total_precipitable_water,surface_pressure," + 
#    "surface_albedo,wind_direction,wind_speed,ghuv-280-400,ghuv-295-385" )
attributes = ( "dhi,air_temperature,dew_point,dni,ghi,ozone," +
    "relative_humidity,solar_zenith_angle,surface_albedo,surface_pressure," + 
    "total_precipitable_water,wind_direction,wind_speed" )
# Choose year of data
#years = range(1998, 2023)
years = range(2019, 2023)
# Set leap year to true or false. True will return
# leap day data if present, false will not.
leap_year = "true"
# Set time interval in minutes, i.e., '30' is half hour intervals.
# Valid intervals are 30 & 60.
interval = "60"
# Specify Coordinated Universal Time (UTC), 'true' will use UTC,
# 'false' will use the local time zone of the data.
# NOTE: In order to use the NSRDB data in SAM, you must specify UTC as 'false'.
# SAM requires the data to be in the local time zone.
utc = "false"
# Your full name, use '+' instead of spaces.
#name = "Ariadna+Porras+Cervantes"
name = "Rodrigo+Munoz"
#name = "Rodrigo+Sanchez"
# Your reason for using the NSRDB.
reason = "beta+testing"
# Your affiliation
affiliation = "my+institution"
# Your email address
#email = "aporrasunam@gmail.com"
email = "rodrigo.munoz@ingenieria.unam.edu"
#email = "rodrigoms95@gmail.com"
mailing_list = "false"
#carpeta_destino = "/Volumes/DATA/data/NSRDB_4km/"
carpeta_destino = "/Volumes/DATA/data/NSRDB_2km/"
# base de datos
#base = "psm3-2-2-download"
base = "full-disc-download"

#Se descarga la información del NSRDB a partir de la API
for i in lat:
    print(f"{i:.3f}°N")
    for j in lon:
        #Se define el nombre de la subcarpeta para cada coordenada
        subcarpeta = f'{i:.2f}_{j:.2f}'
        #Se define la ruta completa de la subcarpeta que se creará
        ruta = f"{carpeta_destino}{subcarpeta}/"
        #Se crea la subcarpeta
        if not os.path.exists(ruta):
            os.mkdir(ruta)
        for y in years:
            #Se define el nombre del archivo .csv
            nombre_archivo = f"{i:.2f}_{j:.2f}_{y}.csv"
            #Se define la ruta absoluta del archivo
            ruta_archivo = f"{ruta}{nombre_archivo}"
            #Se crea el archivo
            if not os.path.exists(ruta_archivo):
                print(ruta_archivo)
                #Declare url string
                url = ( "https://developer.nrel.gov/api/nsrdb/v2/solar/" +
                    f"{base}.csv?wkt=POINT({j}%20{i})&names={y}&leap_day=" +
                    f"{leap_year}&interval={interval}&utc={utc}&full_name=" +
                    f"{name}&email={email}&affiliation={affiliation}" +
                    f"&mailing_list={mailing_list}&reason={reason}&api_key=" +
                    f"{api_key}&attributes={attributes}" )
                #Descargar archivo csv del url 
                df=pd.read_csv(url,skiprows=2)
                #Guardar archivo csv en la subcarpeta
                df.to_csv(ruta + "/" + nombre_archivo, sep = ",",
                    index = False, encoding = "utf-8" )
                #time.sleep(1)
# Out:
# 18.080°N
# 18.100°N
# 18.120°N
# 18.140°N
# 18.160°N
# 18.180°N
# 18.200°N
# 18.220°N
# 18.240°N
# 18.260°N
# 18.280°N
# 18.300°N
# 18.320°N
# 18.340°N
# 18.360°N
# 18.380°N
# 18.400°N
# 18.420°N
# 18.440°N
# 18.460°N
# 18.480°N
# 18.500°N
# 18.520°N
# 18.540°N
# 18.560°N
# 18.580°N
# 18.600°N
# 18.620°N
# 18.640°N
# 18.660°N
# 18.680°N
# 18.700°N
# 18.720°N
# 18.740°N
# 18.760°N
# 18.780°N
# 18.800°N
# 18.820°N
# 18.840°N
# 18.860°N
# 18.880°N
# 18.900°N
# 18.920°N
# 18.940°N
# 18.960°N
# 18.980°N
# 19.000°N
# 19.020°N
# 19.040°N
# 19.060°N
# 19.080°N
# 19.100°N
# 19.120°N
# 19.140°N
# 19.160°N
# 19.180°N
# 19.200°N
# 19.220°N
# 19.240°N
# 19.260°N
# 19.280°N
# 19.300°N
# 19.320°N
# 19.340°N
# 19.360°N
# 19.380°N
# 19.400°N
# 19.420°N
# 19.440°N
# 19.460°N
# 19.480°N
# 19.500°N
# 19.520°N
# 19.540°N
# 19.560°N
# 19.580°N
# 19.600°N
# 19.620°N
# 19.640°N
# 19.660°N
# 19.680°N
# 19.700°N
# 19.720°N
# 19.740°N
# 19.760°N
# 19.780°N
# 19.800°N
# 19.820°N
# 19.840°N
# 19.860°N
# ...
