# %%
# Decarga una lista de archivos de NSRDB

# Importamos las librerías
import os
import pandas as pd
import numpy as np

# Carpeta destino
#carpeta_destino = "/Volumes/DATA/data/NSRDB_4km/"
#carpeta_destino = "/Volumes/DATA/data/NSRDB_2km/"
carpeta_destino = "../data/NSRDB_2km/"
# Creamos la subcarpeta
if not os.path.exists(carpeta_destino): os.mkdir(carpeta_destino)

# Coordenadas
# Conjunto de datos 4 km, TMY y quantile map
#lat = np.arange(18.09, 20.69, 0.04)
#lon = np.arange(-100.46, -97.259, 0.04)
# Conjunto de datos 2 km, duck curve 
#lat = np.arange(14.54, 42.02, 0.02)
lat = np.arange(24.92, 42.02, 0.02)
lon = np.arange(-124.41, -86.69, 0.02)

# Años a descargar
# Conjunto de datos 4 km, TMY y quantile map
#years = range(1998, 2023)
# Conjunto de datos 2 km, duck curve 
years = [2022]

# Time interval in minutes
# Conjunto de datos 4 km, TMY y quantile map
#interval = "60"
# Conjunto de datos 2 km, duck curve 
interval = "30"

# base de datos
# Conjunto de datos 4 km, TMY y quantile map
#base = "psm3-2-2-download"
# Conjunto de datos 2 km, duck curve 
base = "full-disc-download"

# Variables a extraer
# Conjunto de datos 4 km, TMY y quantile map
#attributes = ( "air_temperature,dew_point,dni,dhi,ghi,relative_humidity," +
#    "solar_zenith_angle,total_precipitable_water,surface_pressure," + 
#    "surface_albedo,wind_direction,wind_speed,ghuv-280-400,ghuv-295-385" )
# Conjunto de datos 2 km, duck curve 
attributes = ( "air_temperature,dni,ghi,surface_pressure,wind_speed" )

# API key
#api_key = "vGnsS1lJcyC5dRKax0H9QIs5e6ottm05OB3uzRRL"
api_key = "rzX1wbpMOa9fbeBqDfSk3TRcQSf40Ql7ZDk4t50v"
#api_key = "XmMWV5ub8RTjyqBGPsjMtmrizT2LaHlhRrxdxylj"

# Leap year
leap_year = "true"
# Coordinated Universal Time (UTC)
utc = "false"
# Full name
#name = "Ariadna+Porras+Cervantes"
name = "Rodrigo+Munoz"
#name = "Rodrigo+Sanchez"
# Reason for using the NSRDB.
reason = "beta+testing"
# Affiliation
affiliation = "my+institution"
# Email address
#email = "aporrasunam@gmail.com"
email = "rodrigo.munoz@ingenieria.unam.edu"
#email = "rodrigoms95@gmail.com"
# Mailing list
mailing_list = "false"

# Iteramos para cada coordenada
for i in lat:
    print(f"{i:.3f}°N")
    for j in lon:
        # Definimos el nombre de la subcarpeta para cada coordenada
        subcarpeta = f'{i:.2f}_{j:.2f}'
        # Definimos la ruta completa de la subcarpeta que se creará
        ruta = f"{carpeta_destino}{subcarpeta}/"
        # Creamos la subcarpeta
        if not os.path.exists(ruta): os.mkdir(ruta)
        # Iteramos para cada año
        for y in years:
            # Definimos el nombre del archivo CSV
            nombre_archivo = f"{i:.2f}_{j:.2f}_{y}.csv"
            # Definimos la ruta absoluta del archivo
            ruta_archivo = f"{ruta}{nombre_archivo}"
            # Descargamos el archivo si no existe
            if not os.path.exists(ruta_archivo):
                print(ruta_archivo)
                # URL string
                url = ( "https://developer.nrel.gov/api/nsrdb/v2/solar/" +
                    f"{base}.csv?wkt=POINT({j}%20{i})&names={y}&leap_day=" +
                    f"{leap_year}&interval={interval}&utc={utc}&full_name=" +
                    f"{name}&email={email}&affiliation={affiliation}" +
                    f"&mailing_list={mailing_list}&reason={reason}&api_key=" +
                    f"{api_key}&attributes={attributes}" )
                # Descargamos archivo csv del url 
                try:    df = pd.read_csv(url,skiprows=2)
                # Si no es una coordenada válida no descargamos y seguimso
                except: pass
                # Guardamoa archivo CSV en la subcarpeta
                else:
                    df.to_csv(ruta + "/" + nombre_archivo, sep = ",",
                        index = False, encoding = "utf-8" )
# Out:
# 24.920°N
# ../data/NSRDB_2km/24.92_-124.41/24.92_-124.41_2022.csv
# ../data/NSRDB_2km/24.92_-124.39/24.92_-124.39_2022.csv
# ../data/NSRDB_2km/24.92_-124.37/24.92_-124.37_2022.csv
# ../data/NSRDB_2km/24.92_-124.35/24.92_-124.35_2022.csv
# ../data/NSRDB_2km/24.92_-124.33/24.92_-124.33_2022.csv
# ../data/NSRDB_2km/24.92_-124.31/24.92_-124.31_2022.csv
# ../data/NSRDB_2km/24.92_-124.29/24.92_-124.29_2022.csv
# ../data/NSRDB_2km/24.92_-124.27/24.92_-124.27_2022.csv
# ../data/NSRDB_2km/24.92_-124.25/24.92_-124.25_2022.csv
# ../data/NSRDB_2km/24.92_-124.23/24.92_-124.23_2022.csv
# ../data/NSRDB_2km/24.92_-124.21/24.92_-124.21_2022.csv
# ../data/NSRDB_2km/24.92_-124.19/24.92_-124.19_2022.csv
# ../data/NSRDB_2km/24.92_-124.17/24.92_-124.17_2022.csv
# ../data/NSRDB_2km/24.92_-124.15/24.92_-124.15_2022.csv
# ../data/NSRDB_2km/24.92_-124.13/24.92_-124.13_2022.csv
# ../data/NSRDB_2km/24.92_-124.11/24.92_-124.11_2022.csv
# ../data/NSRDB_2km/24.92_-124.09/24.92_-124.09_2022.csv
# ../data/NSRDB_2km/24.92_-124.07/24.92_-124.07_2022.csv
# ../data/NSRDB_2km/24.92_-124.05/24.92_-124.05_2022.csv
# ../data/NSRDB_2km/24.92_-124.03/24.92_-124.03_2022.csv
# ../data/NSRDB_2km/24.92_-124.01/24.92_-124.01_2022.csv
# ../data/NSRDB_2km/24.92_-123.99/24.92_-123.99_2022.csv
# ../data/NSRDB_2km/24.92_-123.97/24.92_-123.97_2022.csv
# ../data/NSRDB_2km/24.92_-123.95/24.92_-123.95_2022.csv

# %%
import urllib.request
import pandas as pd
import numpy as np
import requests
import os
import time
import urllib

y = 2022
interval = "30"
base = "full-disc-download"
attributes = ( "air_temperature,dni,ghi,surface_pressure,wind_speed" )
api_key = "gyt9NnH5zFXLcbeHV8uvPedVOFi2fWnVmIfvFlNS"
leap_year = "true"
utc = "false"
name = "Gustavo+Sanchez"
reason = "academic+research"
affiliation = "UNAM"
email = "rodrigo.munos@atmosfera.unam.mx"
mailing_list = "false"

lat = np.around(np.arange(24.92, 42.02, 0.02), 2)
lon = np.around(np.arange(-124.41, -86.69, 0.02), 2)
X, Y = np.meshgrid(lon, lat)
points = np.array(list(zip(X.flatten(), Y.flatten()))).astype(str)
points = np.array([" ".join(x) for x in points])
mpoints = []
length = int(lon.shape[0]/2)
for i in range(points.shape[0] // length):  mpoints.append(
    "MULTIPOINT(" + ", ".join(points[i*length:(i+1)*length]) + ")")
j = 1
print(j)
for i, wkt in enumerate(mpoints[::-1][42:60]):
    start = mpoints.index(wkt)*length
    end = (mpoints.index(wkt)+1)*length-1
    if end > len(points): end = len(points)-1
    start_p = points[start].replace(" ", "_")
    end_p = points[end].replace(" ", "_")

    start_lon = f"{float(start_p.split("_")[0])-0.01:.2f}"
    start_lat = f"{float(start_p.split("_")[1])-0.01:.2f}"
    start_p = f"{float(start_lat)+0.01:.2f}_{float(start_lon)+0.01:.2f}"
    end_lon   = f"{float(end_p.split("_")[0])+0.01:.2f}"
    end_lat   = f"{float(end_p.split("_")[1])+0.01:.2f}"
    end_p = f"{float(end_lat)-0.01:.2f}_{float(end_lon)-0.01:.2f}"
    wkt = ( f"POLYGON(({start_lon} {start_lat}, {start_lon} {end_lat}, "
        + f"{end_lon} {end_lat}, {end_lon} {start_lat}, "
        + f"{start_lon} {start_lat}))" )
    wkt.replace(", ", "%2C").replace(" ", "%20")

    wkt = wkt.replace(", ", "%2C").replace(" ", "%20")
    url = ( "https://developer.nrel.gov/api/nsrdb/v2/solar/" +
        f"{base}.json?wkt={wkt}&names={y}&leap_day=" +
        f"{leap_year}&interval={interval}&utc={utc}&full_name=" +
        f"{name}&email={email}&affiliation={affiliation}" +
        f"&mailing_list={mailing_list}&reason={reason}&api_key=" +
        f"{api_key}&attributes={attributes}" )
    url = url.replace(",", "%2C")
    json = requests.get(url).json()

    if json["status"] == 429: raise Exception("Too many requests")
    if ((json["status"]==400) and
        (json["errors"][0][:19]=="User currently owns")):
        raise Exception("Too many requests")
    elif (json["status"]==400): url = None
    elif (json["status"]==200):
        url = json["outputs"]["downloadUrl"]
        print(f"{i} - {start_p}, {end_p}: {url}")
    #data = pd.DataFrame(columns = ["status", "downloadURL",
    #    "start_point", "end_point", "wkt"],
    #    data = [[json["status"], url, start_p, end_p, wkt]])
    #if os.path.exists("../../../temp(recurso_solar/duck_curve/NSRDB_json.csv"):
    #    data = pd.concat([pd.read_csv(
    #        "../../../temp/recurso_solar/duck_curve/NSRDB_json.csv"), data])
    #data.to_csv("../../../temp/recurso_solar/duck_curve/NSRDB_json.csv",
    #    index = False)
    time.sleep(5)
# Out:
# 1
# 0 - 41.58_-105.55, 41.58_-86.71: https://mapfiles.nrel.gov/data/solar/ff3a5f0e1b14ed79e37de46045d0d4a8.zip
# 1 - 41.58_-124.41, 41.58_-105.57: https://mapfiles.nrel.gov/data/solar/6de3a2f1a4d68d4e2eb163e9c39e2bf2.zip
# 2 - 41.56_-105.55, 41.56_-86.71: https://mapfiles.nrel.gov/data/solar/cbff3b6cad35cf48216efd542e08e606.zip
# 3 - 41.56_-124.41, 41.56_-105.57: https://mapfiles.nrel.gov/data/solar/afe761fd1d8e05880813dfbae18e8e7f.zip
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 64
#      61 if json["status"] == 429: raise Exception("Too many requests")
#      62 if ((json["status"]==400) and
#      63     (json["errors"][0][:19]=="User currently owns")):
# ---> 64     raise Exception("Too many requests")
#      65 elif (json["status"]==400): url = None
#      66 elif (json["status"]==200):
#
# Exception: Too many requests

# %%
import urllib.request
import pandas as pd
import numpy as np
import requests
import os
import time
import urllib

y = 2022
interval = "30"
base = "full-disc-download"
attributes = ( "air_temperature,dni,ghi,surface_pressure,wind_speed" )
leap_year = "true"
utc = "false"
reason = "academic+research"
affiliation = "UNAM"
mailing_list = "false"

api_key = "rzX1wbpMOa9fbeBqDfSk3TRcQSf40Ql7ZDk4t50v"
name = "Rodrigo+Sanchez"
email = "rodrigoms95@gmail.com"

lat = np.around(np.arange(24.92, 42.02, 0.02), 2)
lon = np.around(np.arange(-124.41, -86.69, 0.02), 2)
X, Y = np.meshgrid(lon, lat)
points = np.array(list(zip(X.flatten(), Y.flatten()))).astype(str)
points = np.array([" ".join(x) for x in points])
mpoints = []
length = int(lon.shape[0]/2)
for i in range(points.shape[0] // length):  mpoints.append(
    "MULTIPOINT(" + ", ".join(points[i*length:(i+1)*length]) + ")")
j = 3
print(j)
for i, wkt in enumerate(mpoints[::-1][j*20:(j+1)*20]):
    start = mpoints.index(wkt)*length
    end = (mpoints.index(wkt)+1)*length-1
    if end > len(points): end = len(points)-1
    start_p = points[start].replace(" ", "_")
    end_p = points[end].replace(" ", "_")

    start_lon = f"{float(start_p.split("_")[0])-0.01:.2f}"
    start_lat = f"{float(start_p.split("_")[1])-0.01:.2f}"
    start_p = f"{float(start_lat)+0.01:.2f}_{float(start_lon)+0.01:.2f}"
    end_lon   = f"{float(end_p.split("_")[0])+0.01:.2f}"
    end_lat   = f"{float(end_p.split("_")[1])+0.01:.2f}"
    end_p = f"{float(end_lat)-0.01:.2f}_{float(end_lon)-0.01:.2f}"
    wkt = ( f"POLYGON(({start_lon} {start_lat}, {start_lon} {end_lat}, "
        + f"{end_lon} {end_lat}, {end_lon} {start_lat}, "
        + f"{start_lon} {start_lat}))" )
    wkt.replace(", ", "%2C").replace(" ", "%20")

    wkt = wkt.replace(", ", "%2C").replace(" ", "%20")
    url = ( "https://developer.nrel.gov/api/nsrdb/v2/solar/" +
        f"{base}.json?wkt={wkt}&names={y}&leap_day=" +
        f"{leap_year}&interval={interval}&utc={utc}&full_name=" +
        f"{name}&email={email}&affiliation={affiliation}" +
        f"&mailing_list={mailing_list}&reason={reason}&api_key=" +
        f"{api_key}&attributes={attributes}" )
    url = url.replace(",", "%2C")
    json = requests.get(url).json()

    if json["status"] == 429: raise Exception("Too many requests")
    if ((json["status"]==400) and
        (json["errors"][0][:19]=="User currently owns")):
        raise Exception("Too many requests")
    elif (json["status"]==400): url = None
    elif (json["status"]==200):
        url = json["outputs"]["downloadUrl"]
        print(f"{i+1} - {start_p}, {end_p}: {url}")
    time.sleep(5)
# Out:
# 3
# 1 - 41.40_-105.55, 41.40_-86.71: https://mapfiles.nrel.gov/data/solar/9c429a845a9deb6e287bf1569564db13.zip
# 2 - 41.40_-124.41, 41.40_-105.57: https://mapfiles.nrel.gov/data/solar/0cdbf99a8f9f09efdb460349d7013ae1.zip
# 3 - 41.38_-105.55, 41.38_-86.71: https://mapfiles.nrel.gov/data/solar/9d5d7801d2ef4be85e686aba76a2cdbc.zip
# 4 - 41.38_-124.41, 41.38_-105.57: https://mapfiles.nrel.gov/data/solar/181a8cccdaa122569ec989c1cb8c1e74.zip
# 5 - 41.36_-105.55, 41.36_-86.71: https://mapfiles.nrel.gov/data/solar/7ff13e2567a39b0f6cf4e2471db8cd2a.zip
# 6 - 41.36_-124.41, 41.36_-105.57: https://mapfiles.nrel.gov/data/solar/ae77398bfd593560ca2fefc45fb16a63.zip
# 7 - 41.34_-105.55, 41.34_-86.71: https://mapfiles.nrel.gov/data/solar/ccc734b483f56c12d30cf0b13a19b4ad.zip
# 8 - 41.34_-124.41, 41.34_-105.57: https://mapfiles.nrel.gov/data/solar/beb895ebafd8f60f13ea4b02b49fa1c4.zip
# 9 - 41.32_-105.55, 41.32_-86.71: https://mapfiles.nrel.gov/data/solar/d06f5d7177099855d994629211a03b6d.zip
# 10 - 41.32_-124.41, 41.32_-105.57: https://mapfiles.nrel.gov/data/solar/ecb6b8ec6217b9424035908969ae3697.zip
# 11 - 41.30_-105.55, 41.30_-86.71: https://mapfiles.nrel.gov/data/solar/dbe69fa4457c8d69ffc59afd3d249a5f.zip
# 12 - 41.30_-124.41, 41.30_-105.57: https://mapfiles.nrel.gov/data/solar/a2ba435ebbf1e4b6f314eabe5e87726e.zip
# 13 - 41.28_-105.55, 41.28_-86.71: https://mapfiles.nrel.gov/data/solar/2d0e00decd1d685df851e5ac50488861.zip
# 14 - 41.28_-124.41, 41.28_-105.57: https://mapfiles.nrel.gov/data/solar/62b15ccf95560591344abcfefd213eb5.zip
# 15 - 41.26_-105.55, 41.26_-86.71: https://mapfiles.nrel.gov/data/solar/410c02cd35d06a535f31f271cb96c3aa.zip
# 16 - 41.26_-124.41, 41.26_-105.57: https://mapfiles.nrel.gov/data/solar/c03a15b7ea40cf5983fd774c59ee31c2.zip
# 17 - 41.24_-105.55, 41.24_-86.71: https://mapfiles.nrel.gov/data/solar/e4498e659d4eca6e3306c8482aac2fc9.zip
# 18 - 41.24_-124.41, 41.24_-105.57: https://mapfiles.nrel.gov/data/solar/006a2cde22e8a41ec4fdd8b123b7ec47.zip
# 19 - 41.22_-105.55, 41.22_-86.71: https://mapfiles.nrel.gov/data/solar/a1a1cf270ffd65208003e711cb4e9a8a.zip
# 20 - 41.22_-124.41, 41.22_-105.57: https://mapfiles.nrel.gov/data/solar/c5f823b6788478962b59326c39a25ac1.zip

# %%
import urllib.request
import pandas as pd
import numpy as np
import requests
import os
import time
import urllib

y = 2022
interval = "30"
base = "full-disc-download"
attributes = ( "air_temperature,dni,ghi,surface_pressure,wind_speed" )
leap_year = "true"
utc = "false"
reason = "academic+research"
affiliation = "UNAM"
mailing_list = "false"

api_key = "XmMWV5ub8RTjyqBGPsjMtmrizT2LaHlhRrxdxylj"
name = "Rodrigo+Munoz"
email = "rodrigo.munoz@ingenieria.unam.edu"

lat = np.around(np.arange(24.92, 42.02, 0.02), 2)
lon = np.around(np.arange(-124.41, -86.69, 0.02), 2)
X, Y = np.meshgrid(lon, lat)
points = np.array(list(zip(X.flatten(), Y.flatten()))).astype(str)
points = np.array([" ".join(x) for x in points])
mpoints = []
length = int(lon.shape[0]/2)
for i in range(points.shape[0] // length):  mpoints.append(
    "MULTIPOINT(" + ", ".join(points[i*length:(i+1)*length]) + ")")
j = 4
print(j)
for i, wkt in enumerate(mpoints[::-1][j*20:(j+1)*20]):
    start = mpoints.index(wkt)*length
    end = (mpoints.index(wkt)+1)*length-1
    if end > len(points): end = len(points)-1
    start_p = points[start].replace(" ", "_")
    end_p = points[end].replace(" ", "_")

    start_lon = f"{float(start_p.split("_")[0])-0.01:.2f}"
    start_lat = f"{float(start_p.split("_")[1])-0.01:.2f}"
    start_p = f"{float(start_lat)+0.01:.2f}_{float(start_lon)+0.01:.2f}"
    end_lon   = f"{float(end_p.split("_")[0])+0.01:.2f}"
    end_lat   = f"{float(end_p.split("_")[1])+0.01:.2f}"
    end_p = f"{float(end_lat)-0.01:.2f}_{float(end_lon)-0.01:.2f}"
    wkt = ( f"POLYGON(({start_lon} {start_lat}, {start_lon} {end_lat}, "
        + f"{end_lon} {end_lat}, {end_lon} {start_lat}, "
        + f"{start_lon} {start_lat}))" )
    wkt.replace(", ", "%2C").replace(" ", "%20")

    wkt = wkt.replace(", ", "%2C").replace(" ", "%20")
    url = ( "https://developer.nrel.gov/api/nsrdb/v2/solar/" +
        f"{base}.json?wkt={wkt}&names={y}&leap_day=" +
        f"{leap_year}&interval={interval}&utc={utc}&full_name=" +
        f"{name}&email={email}&affiliation={affiliation}" +
        f"&mailing_list={mailing_list}&reason={reason}&api_key=" +
        f"{api_key}&attributes={attributes}" )
    url = url.replace(",", "%2C")
    json = requests.get(url).json()

    if json["status"] == 429: raise Exception("Too many requests")
    if ((json["status"]==400) and
        (json["errors"][0][:19]=="User currently owns")):
        raise Exception("Too many requests")
    elif (json["status"]==400): url = None
    elif (json["status"]==200):
        url = json["outputs"]["downloadUrl"]
        print(f"{i+1} - {start_p}, {end_p}: {url}")
    time.sleep(5)
# Out:
# 4
# 1 - 41.20_-105.55, 41.20_-86.71: https://mapfiles.nrel.gov/data/solar/0452b029c895e2dee6ed73fdd57e254e.zip
# 2 - 41.20_-124.41, 41.20_-105.57: https://mapfiles.nrel.gov/data/solar/7d0f24b3fcc0a3d1d20cd07af716bf1f.zip
# 3 - 41.18_-105.55, 41.18_-86.71: https://mapfiles.nrel.gov/data/solar/3b47627ec68868ed7479868ed6458494.zip
# 4 - 41.18_-124.41, 41.18_-105.57: https://mapfiles.nrel.gov/data/solar/1b0ea2c7bad2fb2ec42839e62e190ed6.zip
# 5 - 41.16_-105.55, 41.16_-86.71: https://mapfiles.nrel.gov/data/solar/f279633bf0287fdec14f438e41205f56.zip
# 6 - 41.16_-124.41, 41.16_-105.57: https://mapfiles.nrel.gov/data/solar/df7a6d1abc6be839ae23807752c138aa.zip
# 7 - 41.14_-105.55, 41.14_-86.71: https://mapfiles.nrel.gov/data/solar/3baf1f0d659d2d4b9be88e53b5c5c8fe.zip
# 8 - 41.14_-124.41, 41.14_-105.57: https://mapfiles.nrel.gov/data/solar/34085bd242c0796ce7425e716fdc000b.zip
# 9 - 41.12_-105.55, 41.12_-86.71: https://mapfiles.nrel.gov/data/solar/a255c9a5abdaf7897eabb241f3f1da1b.zip
# 10 - 41.12_-124.41, 41.12_-105.57: https://mapfiles.nrel.gov/data/solar/d4770c77f691849c335657a753365335.zip
# 11 - 41.10_-105.55, 41.10_-86.71: https://mapfiles.nrel.gov/data/solar/b8c373ff2f80b521730e877e5d693c43.zip
# 12 - 41.10_-124.41, 41.10_-105.57: https://mapfiles.nrel.gov/data/solar/32b485e7714d11da7618b7c74feac94b.zip
# 13 - 41.08_-105.55, 41.08_-86.71: https://mapfiles.nrel.gov/data/solar/84814db52d27f263f7790cf3cf44fa1b.zip
# 14 - 41.08_-124.41, 41.08_-105.57: https://mapfiles.nrel.gov/data/solar/efe758cc6e5d3ccdc003b0588f3b2476.zip
# 15 - 41.06_-105.55, 41.06_-86.71: https://mapfiles.nrel.gov/data/solar/ba6bb248e3b7586f88befa6d3c2327be.zip
# 16 - 41.06_-124.41, 41.06_-105.57: https://mapfiles.nrel.gov/data/solar/2557e3a036e3e82c236ce18a6928231b.zip
# 17 - 41.04_-105.55, 41.04_-86.71: https://mapfiles.nrel.gov/data/solar/71887da41f2a701cfc128d614e6c9d86.zip
# 18 - 41.04_-124.41, 41.04_-105.57: https://mapfiles.nrel.gov/data/solar/b115923ee1a982ce314c33492ed75bf3.zip
# 19 - 41.02_-105.55, 41.02_-86.71: https://mapfiles.nrel.gov/data/solar/358dbaa85f9949fab9c8895191a9276e.zip
# 20 - 41.02_-124.41, 41.02_-105.57: https://mapfiles.nrel.gov/data/solar/342dd75d6f60052b7b829caf7dfc6a74.zip

# %%
import os
import shutil

temp_dir = "/home/rodr/temp/recurso_solar/duck_curve/folders/"
dest_dir = "/home/rodr/Datos/NSRDB_2km_duck/"
#dest_dir = "/home/rodr/temp/recurso_solar/duck_curve/files/"

if not os.path.exists(temp_dir): os.mkdir(temp_dir)
if not os.path.exists(dest_dir): os.mkdir(dest_dir)

folders = os.listdir(temp_dir)
for folder_i in folders:
    files = os.listdir(f"{temp_dir}{folder_i}")
    dir_n = [f"{dest_dir}{x[8:-9]}" for x in files]
    files_n = [f"{dest_dir}{x[8:-9]}/{x[5:]}" for x in files]
    for d in dir_n: 
        if not os.path.exists(d): os.mkdir(d)
    for i in range(len(files_n)): 
        if not os.path.exists(files_n[i]):
            shutil.move(f"{temp_dir}{folder_i}/{files[i]}", files_n[i])
